# %% [markdown]
# # Tests of python

# %%
the_sum = 1 + 1
print(the_sum)
# Out:
# 2

# %% [markdown]
# ## Deployment 1 average

# %%
import numpy as np

Deployment_1 = [50, 52, 55, 48, 50, 49, 51, 53, 52, 54]
np.average(Deployment_1)
# Out:
# 51.4

# %% [markdown]
# ## Deployment 1 Variance

# %%
np.var(Deployment_1)
# Out:
# 4.4399999999999995

# %% [markdown]
# ## Deployment 1 standard deviation

# %%
np.std(Deployment_1)
# Out:
# 2.1071307505705477

# %%
Deployment_2 = [45, 48, 47, 50, 55, 52, 53, 49, 50, 48]
Deployment_3 = [60, 58, 62, 63, 59, 61, 57, 60, 58, 65]
Deployment_4 = [40, 42, 41, 45, 39, 43, 44, 42, 41, 40]

import matplotlib.pyplot as plt

plt.plot(Deployment_1)
plt.plot(Deployment_2)
plt.plot(Deployment_3)
plt.plot(Deployment_4)
plt.show()
